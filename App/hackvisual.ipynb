# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy import genfromtxt

# %%
a = np.load('hackathon-three-cities_all_data_L1.npy')
atest = np.load('hackathon-three-cities_all_data_L2.npy')

# %%
f = open('text.txt','w')
for j in range(0,3001):
    for i in range(0,1512):
        f.write(str(atest[i,j]) + '\t')
    f.write('\n')

# %%
b = genfromtxt('my_result.csv', delimiter=',')
btest = genfromtxt('hackathon-three-cities_L2_horizons_train.csv', delimiter=',')
x = np.arange(1512)

# %%
plt.figure(figsize=(20,20))
plt.imshow(a.transpose()[0:1500,])
plt.plot(x,b[1:,1],color='red')
plt.show()

# %%
b[1:,1]
# Out:
# array([nan, nan, nan, ..., nan, nan, nan])
